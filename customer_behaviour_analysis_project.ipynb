# %% [markdown]
# ### EDA

# %%
# importing pandas library
import pandas as pd

# %%
# python package installer 
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\prabhat\appdata\roaming\python\python312\site-packages (3.0.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\prabhat\appdata\roaming\python\python312\site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\prabhat\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\prabhat\appdata\roaming\python\python312\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\prabhat\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 23.2.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#importing dataset
df=pd.read_csv("customer_shopping_behavior.csv")

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0            2701   22  Female        T-shirt     Clothing
# 1             521   51    Male     Sunglasses  Accessories
# 2            3157   18  Female          Shirt     Clothing
# 3            1687   22    Male         Gloves  Accessories
# 4            2929   40  Female        Jewelry  Accessories
# ...           ...  ...     ...            ...          ...
# 5045          913   24    Male         Hoodie     Clothing
# 5046         3466   19  Female       Backpack  Accessories
# 5047         3572   70  Female          Skirt     Clothing
# 5048         3195   43  Female       Sneakers     Footwear
# 5049         1832   62    Male         Blouse     Clothing
#
#       Purchase Amount (USD)        Location Size   Color  Season  \
# 0                      68.0      California   XL   Olive  Winter
# 1                      84.0  South Carolina    M   White  Spring
# 2                      50.0         Montana    M   Black  Winter
# 3                      75.0        Illinois    L     Red    Fall
# 4                      80.0         Alabama    L  Yellow  Spring
# ...                     ...             ...  ...     ...     ...
# 5045                   56.0        Arkansas    M   Green  Winter
# 5046                   53.0            Iowa    M    Gold  Spring
# 5047                   27.0    North Dakota    M   White  Summer
# 5048                   52.0        Maryland    L    Gold  Summer
# 5049                   71.0           Maine    M    Cyan  Summer
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 0               3.2                  No        Standard               No
# 1               3.9                 Yes   Free Shipping              Yes
# 2               3.1                  No  2-Day Shipping               No
# 3               4.2                  No    Store Pickup               No
# 4               3.6                  No    Store Pickup               No
# ...             ...                 ...             ...              ...
# 5045            3.4                 Yes    Next Day Air              Yes
# 5046            3.4                  No        Standard               No
# 5047            3.2                  No        Standard               No
# 5048            4.6                  No        Standard               No
# 5049            3.3                  No   Free Shipping               No
#
#       Previous Purchases Payment Method Frequency of Purchases
# 0                   36.0           Cash                 Weekly
# 1                   20.0     Debit Card              Quarterly
# 2                   18.0           Cash                Monthly
# 3                   25.0           Cash               Annually
# 4                   17.0    Credit Card                 Weekly
# ...                  ...            ...                    ...
# 5045                32.0  Bank Transfer                Monthly
# 5046                31.0     Debit Card                 Weekly
# 5047                15.0  Bank Transfer         Every 3 Months
# 5048                10.0    Credit Card              Bi-Weekly
# 5049                 5.0  Bank Transfer         Every 3 Months
#
# [5050 rows x 17 columns]

# %%
df.head
# Out:
# <bound method NDFrame.head of       Customer ID  Age  Gender Item Purchased     Category  \
# 0            2701   22  Female        T-shirt     Clothing
# 1             521   51    Male     Sunglasses  Accessories
# 2            3157   18  Female          Shirt     Clothing
# 3            1687   22    Male         Gloves  Accessories
# 4            2929   40  Female        Jewelry  Accessories
# ...           ...  ...     ...            ...          ...
# 5045          913   24    Male         Hoodie     Clothing
# 5046         3466   19  Female       Backpack  Accessories
# 5047         3572   70  Female          Skirt     Clothing
# 5048         3195   43  Female       Sneakers     Footwear
# 5049         1832   62    Male         Blouse     Clothing
#
#       Purchase Amount (USD)        Location Size   Color  Season  \
# 0                      68.0      California   XL   Olive  Winter
# 1                      84.0  South Carolina    M   White  Spring
# 2                      50.0         Montana    M   Black  Winter
# 3                      75.0        Illinois    L     Red    Fall
# 4                      80.0         Alabama    L  Yellow  Spring
# ...                     ...             ...  ...     ...     ...
# 5045                   56.0        Arkansas    M   Green  Winter
# 5046                   53.0            Iowa    M    Gold  Spring
# 5047                   27.0    North Dakota    M   White  Summer
# 5048                   52.0        Maryland    L    Gold  Summer
# 5049                   71.0           Maine    M    Cyan  Summer
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 0               3.2                  No        Standard               No
# 1               3.9                 Yes   Free Shipping              Yes
# 2               3.1                  No  2-Day Shipping               No
# 3               4.2                  No    Store Pickup               No
# 4               3.6                  No    Store Pickup               No
# ...             ...                 ...             ...              ...
# 5045            3.4                 Yes    Next Day Air              Yes
# 5046            3.4                  No        Standard               No
# 5047            3.2                  No        Standard               No
# 5048            4.6                  No        Standard               No
# 5049            3.3                  No   Free Shipping               No
#
#       Previous Purchases Payment Method Frequency of Purchases
# 0                   36.0           Cash                 Weekly
# 1                   20.0     Debit Card              Quarterly
# 2                   18.0           Cash                Monthly
# 3                   25.0           Cash               Annually
# 4                   17.0    Credit Card                 Weekly
# ...                  ...            ...                    ...
# 5045                32.0  Bank Transfer                Monthly
# 5046                31.0     Debit Card                 Weekly
# 5047                15.0  Bank Transfer         Every 3 Months
# 5048                10.0    Credit Card              Bi-Weekly
# 5049                 5.0  Bank Transfer         Every 3 Months
#
# [5050 rows x 17 columns]>

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
#
#    Purchase Amount (USD)        Location Size   Color  Season  Review Rating  \
# 0                   68.0      California   XL   Olive  Winter            3.2
# 1                   84.0  South Carolina    M   White  Spring            3.9
# 2                   50.0         Montana    M   Black  Winter            3.1
# 3                   75.0        Illinois    L     Red    Fall            4.2
# 4                   80.0         Alabama    L  Yellow  Spring            3.6
#
#   Subscription Status   Shipping Type Discount Applied  Previous Purchases  \
# 0                  No        Standard               No                36.0
# 1                 Yes   Free Shipping              Yes                20.0
# 2                  No  2-Day Shipping               No                18.0
# 3                  No    Store Pickup               No                25.0
# 4                  No    Store Pickup               No                17.0
#
#   Payment Method Frequency of Purchases
# 0           Cash                 Weekly
# 1     Debit Card              Quarterly
# 2           Cash                Monthly
# 3           Cash               Annually
# 4    Credit Card                 Weekly

# %%
len(df)
# Out:
# 5050

# %%
df.shape
# Out:
# (5050, 17)

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  5050.000000  5050.000000            4494.000000    4449.000000
# mean   2519.570891    44.150495             144.765236       3.668195
# std    1470.402964    15.282328             275.590101       0.865357
# min       1.000000    18.000000              10.120000       1.000000
# 25%    1252.250000    31.000000              41.000000       3.000000
# 50%    2499.500000    44.000000              65.000000       3.700000
# 75%    3740.750000    57.000000              89.000000       4.400000
# max    5099.000000    70.000000            1499.760000       5.000000
#
#        Previous Purchases
# count         4502.000000
# mean            25.221901
# std             14.521635
# min              0.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.describe(include = "all")
# Out:
#         Customer ID          Age Gender Item Purchased  Category  \
# count   5050.000000  5050.000000   5050           5050      5050
# unique          NaN          NaN      3             30         5
# top             NaN          NaN   Male          Shirt  Clothing
# freq            NaN          NaN   3018            320      2130
# mean    2519.570891    44.150495    NaN            NaN       NaN
# std     1470.402964    15.282328    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%     1252.250000    31.000000    NaN            NaN       NaN
# 50%     2499.500000    44.000000    NaN            NaN       NaN
# 75%     3740.750000    57.000000    NaN            NaN       NaN
# max     5099.000000    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD)  Location  Size  Color  Season  Review Rating  \
# count             4494.000000      5050  4680   5050    5050    4449.000000
# unique                    NaN        54     4     25       5            NaN
# top                       NaN  New York     M  Black  Spring            NaN
# freq                      NaN       337  1981    404    1280            NaN
# mean               144.765236       NaN   NaN    NaN     NaN       3.668195
# std                275.590101       NaN   NaN    NaN     NaN       0.865357
# min                 10.120000       NaN   NaN    NaN     NaN       1.000000
# 25%                 41.000000       NaN   NaN    NaN     NaN       3.000000
# 50%                 65.000000       NaN   NaN    NaN     NaN       3.700000
# 75%                 89.000000       NaN   NaN    NaN     NaN       4.400000
# max               1499.760000       NaN   NaN    NaN     NaN       5.000000
#
#        Subscription Status Shipping Type Discount Applied  Previous Purchases  \
# count                 5050          5050             5050         4502.000000
# unique                   2             6                2                 NaN
# top                     No      Standard               No                 NaN
# freq                  3462          1213             2789                 NaN
# mean                   NaN           NaN              NaN           25.221901
# std                    NaN           NaN              NaN           14.521635
# min                    NaN           NaN              NaN            0.000000
# 25%                    NaN           NaN              NaN           13.000000
# 50%                    NaN           NaN              NaN           25.000000
# 75%                    NaN           NaN              NaN           38.000000
# max                    NaN           NaN              NaN           50.000000
#
#        Payment Method Frequency of Purchases
# count            5050                   5050
# unique              6                      7
# top       Credit Card                Monthly
# freq              954                    946
# mean              NaN                    NaN
# std               NaN                    NaN
# min               NaN                    NaN
# 25%               NaN                    NaN
# 50%               NaN                    NaN
# 75%               NaN                    NaN
# max               NaN                    NaN

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5050 entries, 0 to 5049
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             5050 non-null   int64
#  1   Age                     5050 non-null   int64
#  2   Gender                  5050 non-null   str
#  3   Item Purchased          5050 non-null   str
#  4   Category                5050 non-null   str
#  5   Purchase Amount (USD)   4494 non-null   float64
#  6   Location                5050 non-null   str
#  7   Size                    4680 non-null   str
#  8   Color                   5050 non-null   str
#  9   Season                  5050 non-null   str
#  10  Review Rating           4449 non-null   float64
#  11  Subscription Status     5050 non-null   str
#  12  Shipping Type           5050 non-null   str
#  13  Discount Applied        5050 non-null   str
#  14  Previous Purchases      4502 non-null   float64
#  15  Payment Method          5050 non-null   str
#  16  Frequency of Purchases  5050 non-null   str
# dtypes: float64(3), int64(2), str(12)
# memory usage: 670.8 KB

# %%
df.isnull()
# Out:
#       Customer ID    Age  Gender  Item Purchased  Category  \
# 0           False  False   False           False     False
# 1           False  False   False           False     False
# 2           False  False   False           False     False
# 3           False  False   False           False     False
# 4           False  False   False           False     False
# ...           ...    ...     ...             ...       ...
# 5045        False  False   False           False     False
# 5046        False  False   False           False     False
# 5047        False  False   False           False     False
# 5048        False  False   False           False     False
# 5049        False  False   False           False     False
#
#       Purchase Amount (USD)  Location   Size  Color  Season  Review Rating  \
# 0                     False     False  False  False   False          False
# 1                     False     False  False  False   False          False
# 2                     False     False  False  False   False          False
# 3                     False     False  False  False   False          False
# 4                     False     False  False  False   False          False
# ...                     ...       ...    ...    ...     ...            ...
# 5045                  False     False  False  False   False          False
# 5046                  False     False  False  False   False          False
# 5047                  False     False  False  False   False          False
# 5048                  False     False  False  False   False          False
# 5049                  False     False  False  False   False          False
#
#       Subscription Status  Shipping Type  Discount Applied  \
# 0                   False          False             False
# 1                   False          False             False
# 2                   False          False             False
# 3                   False          False             False
# 4                   False          False             False
# ...                   ...            ...               ...
# 5045                False          False             False
# 5046                False          False             False
# 5047                False          False             False
# 5048                False          False             False
# 5049                False          False             False
#
#       Previous Purchases  Payment Method  Frequency of Purchases
# 0                  False           False                   False
# 1                  False           False                   False
# 2                  False           False                   False
# 3                  False           False                   False
# 4                  False           False                   False
# ...                  ...             ...                     ...
# 5045               False           False                   False
# 5046               False           False                   False
# 5047               False           False                   False
# 5048               False           False                   False
# 5049               False           False                   False
#
# [5050 rows x 17 columns]

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                      370
# Color                       0
# Season                      0
# Review Rating             601
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# ### Data Cleaning

# %%
df['item purchased'].unique()
# Out:
# -------------------------------------------------------------------
# KeyError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'item purchased'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                          Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df['item purchased'].unique()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'item purchased'

# %%
df['Item Purchased'].unique()
# Out:
# <StringArray>
# [   'T-shirt', 'Sunglasses',      'Shirt',     'Gloves',    'Jewelry',
#      'Shorts',        'Hat',    'Handbag',      'Shoes',       'Coat',
#      'Laptop',     'Hoodie',      'Phone',     'Jacket',      'Pants',
#    'Backpack',      'Socks',      'Jeans',        'Bag',       'Belt',
#       'Watch', 'Headphones',     'Blouse',    'Sandals',      'Skirt',
#     'Sweater',      'Scarf',   'Sneakers',      'Boots',      'Dress']
# Length: 30, dtype: str

# %%
df['Category'].unique()
# Out:
# <StringArray>
# ['Clothing', 'Accessories', 'Outerwear', 'Electronics', 'Footwear']
# Length: 5, dtype: str

# %%
df.groupby('Category')['Item Purchased'].unique()
# Out:
# Category
# Accessories    [Sunglasses, Gloves, Jewelry, Hat, Handbag, Ph...
# Clothing       [T-shirt, Shirt, Shorts, Shoes, Hoodie, Phone,...
# Electronics    [Laptop, Phone, Watch, Bag, Shoes, Shirt, Head...
# Footwear                       [Shoes, Sandals, Sneakers, Boots]
# Outerwear                                         [Coat, Jacket]
# Name: Item Purchased, dtype: object

# %%
pd.set_option('display.max_colwidth',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df.groupby('Category')['Item Purchased'].unique()
# Out:
# Category
# Accessories               [Sunglasses, Gloves, Jewelry, Hat, Handbag, Phone, Backpack, Belt, Bag, Headphones, Scarf, Watch, Shirt, Shoes, Laptop]
# Clothing       [T-shirt, Shirt, Shorts, Shoes, Hoodie, Phone, Pants, Socks, Jeans, Bag, Blouse, Skirt, Sweater, Watch, Laptop, Dress, Headphones]
# Electronics                                                                                 [Laptop, Phone, Watch, Bag, Shoes, Shirt, Headphones]
# Footwear                                                                                                        [Shoes, Sandals, Sneakers, Boots]
# Outerwear                                                                                                                          [Coat, Jacket]
# Name: Item Purchased, dtype: object

# %%
correct_mapping = {
    # Clothing
    "T-shirt": "Clothing", "Shirt": "Clothing", "Shorts": "Clothing",
    "Hoodie": "Clothing", "Pants": "Clothing", "Socks": "Clothing",
    "Jeans": "Clothing", "Blouse": "Clothing", "Skirt": "Clothing",
    "Sweater": "Clothing", "Dress": "Clothing",

    # Accessories
    "Sunglasses": "Accessories", "Gloves": "Accessories",
    "Jewelry": "Accessories", "Hat": "Accessories",
    "Handbag": "Accessories", "Backpack": "Accessories",
    "Belt": "Accessories", "Scarf": "Accessories",
    "Bag": "Accessories",

    # Electronics
    "Laptop": "Electronics", "Phone": "Electronics",
    "Headphones": "Electronics", "Watch": "Electronics",

    # Footwear
    "Shoes": "Footwear", "Sandals": "Footwear",
    "Sneakers": "Footwear", "Boots": "Footwear",

    # Outerwear
    "Coat": "Outerwear", "Jacket": "Outerwear"
}

# %%
correct_mapping
# Out:
# {'T-shirt': 'Clothing',
#  'Shirt': 'Clothing',
#  'Shorts': 'Clothing',
#  'Hoodie': 'Clothing',
#  'Pants': 'Clothing',
#  'Socks': 'Clothing',
#  'Jeans': 'Clothing',
#  'Blouse': 'Clothing',
#  'Skirt': 'Clothing',
#  'Sweater': 'Clothing',
#  'Dress': 'Clothing',
#  'Sunglasses': 'Accessories',
#  'Gloves': 'Accessories',
#  'Jewelry': 'Accessories',
#  'Hat': 'Accessories',
#  'Handbag': 'Accessories',
#  'Backpack': 'Accessories',
#  'Belt': 'Accessories',
#  'Scarf': 'Accessories',
#  'Bag': 'Accessories',
#  'Laptop': 'Electronics',
#  'Phone': 'Electronics',
#  'Headphones': 'Electronics',
#  'Watch': 'Electronics',
#  'Shoes': 'Footwear',
#  'Sandals': 'Footwear',
#  'Sneakers': 'Footwear',
#  'Boots': 'Footwear',
#  'Coat': 'Outerwear',
#  'Jacket': 'Outerwear'}

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
#
#    Purchase Amount (USD)        Location Size   Color  Season  Review Rating  \
# 0                   68.0      California   XL   Olive  Winter            3.2
# 1                   84.0  South Carolina    M   White  Spring            3.9
# 2                   50.0         Montana    M   Black  Winter            3.1
# 3                   75.0        Illinois    L     Red    Fall            4.2
# 4                   80.0         Alabama    L  Yellow  Spring            3.6
#
#   Subscription Status   Shipping Type Discount Applied  Previous Purchases  \
# 0                  No        Standard               No                36.0
# 1                 Yes   Free Shipping              Yes                20.0
# 2                  No  2-Day Shipping               No                18.0
# 3                  No    Store Pickup               No                25.0
# 4                  No    Store Pickup               No                17.0
#
#   Payment Method Frequency of Purchases
# 0           Cash                 Weekly
# 1     Debit Card              Quarterly
# 2           Cash                Monthly
# 3           Cash               Annually
# 4    Credit Card                 Weekly

# %%
df['Category'] = df['Item Purchased'].map(correct_mapping)

# %%
df.groupby('Category')['Item Purchased'].unique()
# Out:
# Category
# Accessories                 [Sunglasses, Gloves, Jewelry, Hat, Handbag, Backpack, Bag, Belt, Scarf]
# Clothing       [T-shirt, Shirt, Shorts, Hoodie, Pants, Socks, Jeans, Blouse, Skirt, Sweater, Dress]
# Electronics                                                      [Laptop, Phone, Watch, Headphones]
# Footwear                                                          [Shoes, Sandals, Sneakers, Boots]
# Outerwear                                                                            [Coat, Jacket]
# Name: Item Purchased, dtype: object

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                      370
# Color                       0
# Season                      0
# Review Rating             601
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# ### Treating null values

# %% [markdown]
# #### size

# %%
df['Size'].unique()
# Out:
# <StringArray>
# ['XL', 'M', 'L', 'S', nan]
# Length: 5, dtype: str

# %%
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories    [M, L, S, XL, nan]
# Clothing       [XL, M, S, L, nan]
# Electronics    [nan, L, S, M, XL]
# Footwear       [M, L, S, nan, XL]
# Outerwear           [XL, L, S, M]
# Name: Size, dtype: object

# %%
df.groupby('Item Purchased')['Size'].unique()
# Out:
# Item Purchased
# Backpack           [M, S, L, XL]
# Bag           [M, L, nan, XL, S]
# Belt               [M, S, XL, L]
# Blouse             [M, L, S, XL]
# Boots              [L, M, XL, S]
# Coat               [XL, M, S, L]
# Dress              [XL, M, L, S]
# Gloves             [L, M, S, XL]
# Handbag            [S, XL, M, L]
# Hat                [M, L, S, XL]
# Headphones    [S, M, nan, L, XL]
# Hoodie             [M, L, S, XL]
# Jacket             [L, S, M, XL]
# Jeans              [L, M, XL, S]
# Jewelry            [L, XL, M, S]
# Laptop        [nan, M, S, XL, L]
# Pants              [L, M, XL, S]
# Phone         [nan, L, S, M, XL]
# Sandals            [M, S, L, XL]
# Scarf              [M, L, S, XL]
# Shirt         [M, XL, L, S, nan]
# Shoes         [M, L, nan, XL, S]
# Shorts             [S, M, L, XL]
# Skirt              [S, L, M, XL]
# Sneakers           [S, M, L, XL]
# Socks              [M, XL, L, S]
# Sunglasses         [M, L, S, XL]
# Sweater            [M, S, L, XL]
# T-shirt            [XL, M, S, L]
# Watch         [nan, M, L, XL, S]
# Name: Size, dtype: object

# %%
df.groupby('Category')['Item Purchased'].unique()
# Out:
# Category
# Accessories                 [Sunglasses, Gloves, Jewelry, Hat, Handbag, Backpack, Bag, Belt, Scarf]
# Clothing       [T-shirt, Shirt, Shorts, Hoodie, Pants, Socks, Jeans, Blouse, Skirt, Sweater, Dress]
# Electronics                                                      [Laptop, Phone, Watch, Headphones]
# Footwear                                                          [Shoes, Sandals, Sneakers, Boots]
# Outerwear                                                                            [Coat, Jacket]
# Name: Item Purchased, dtype: object

# %%
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories    [M, L, S, XL, nan]
# Clothing       [XL, M, S, L, nan]
# Electronics    [nan, L, S, M, XL]
# Footwear       [M, L, S, nan, XL]
# Outerwear           [XL, L, S, M]
# Name: Size, dtype: object

# %%
# Treating null values or replacing all values in electronic category
df.loc[df['Category'] == 'Electronics','Size'] = "Not Applicable"

# %%
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories    [M, L, S, XL, nan]
# Clothing       [XL, M, S, L, nan]
# Electronics      [Not Applicable]
# Footwear       [M, L, S, nan, XL]
# Outerwear           [XL, L, S, M]
# Name: Size, dtype: object

# %%
# Treating null values or replacing all values in Accessories category
df.loc[df['Category'] == 'Accessories','Size'] = "Free Size"

# %%
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories           [Free Size]
# Clothing       [XL, M, S, L, nan]
# Electronics      [Not Applicable]
# Footwear       [M, L, S, nan, XL]
# Outerwear           [XL, L, S, M]
# Name: Size, dtype: object

# %%
# Treating null values or replacing all values in Footwear category
df.loc[df['Category'] == 'Footwear','Size'] = "Not Available"

# %%
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories           [Free Size]
# Clothing       [XL, M, S, L, nan]
# Electronics      [Not Applicable]
# Footwear          [Not Available]
# Outerwear           [XL, L, S, M]
# Name: Size, dtype: object

# %%
# Treating null values or replacing all values in Clothing category
df.loc[(df['Category'] == 'Clothing') & (df['Size'].isnull()),'Size'] = df[df['Category'] == 'Clothing']['Size'].mode()[0]

# %%
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories         [Free Size]
# Clothing          [XL, M, S, L]
# Electronics    [Not Applicable]
# Footwear        [Not Available]
# Outerwear         [XL, L, S, M]
# Name: Size, dtype: object

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating             601
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# ####  Review Rating

# %%
# mean of Review Rating
df['Review Rating'].mean()
# Out:
# np.float64(3.668195100022477)

# %%
# median of Review Rating
df['Review Rating'].median()
# Out:
# np.float64(3.7)

# %%
# mode of Review Rating
df['Review Rating'].mode()
# Out:
# 0    4.0
# Name: Review Rating, dtype: float64

# %%
df.groupby("Item Purchased")['Review Rating'].mean()
# Out:
# Item Purchased
# Backpack      3.758333
# Bag           3.168539
# Belt          3.762963
# Blouse        3.677647
# Boots         3.813194
# Coat          3.721875
# Dress         3.750000
# Gloves        3.862774
# Handbag       3.771975
# Hat           3.796753
# Headphones    3.075949
# Hoodie        3.716779
# Jacket        3.761446
# Jeans         3.651969
# Jewelry       3.761850
# Laptop        3.191176
# Pants         3.720833
# Phone         2.939024
# Sandals       3.837037
# Scarf         3.702564
# Shirt         3.427273
# Shoes         3.546154
# Shorts        3.722981
# Skirt         3.779747
# Sneakers      3.757931
# Socks         3.755063
# Sunglasses    3.745679
# Sweater       3.768712
# T-shirt       3.790541
# Watch         3.100000
# Name: Review Rating, dtype: float64

# %%
#filling null values of review rating with the mean of each item purchased
df['Review Rating'] = df['Review Rating'].fillna(df.groupby('Item Purchased')['Review Rating'].transform('mean'))

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %%
df.head(10)
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
# 5         3583   23  Female         Shorts     Clothing
# 6         1135   62    Male        T-shirt     Clothing
# 7         1411   61    Male            Hat  Accessories
# 8          113   37    Male         Gloves  Accessories
# 9          166   42    Male        Handbag  Accessories
#
#    Purchase Amount (USD)        Location       Size   Color  Season  \
# 0                   68.0      California         XL   Olive  Winter
# 1                   84.0  South Carolina  Free Size   White  Spring
# 2                   50.0         Montana          M   Black  Winter
# 3                   75.0        Illinois  Free Size     Red    Fall
# 4                   80.0         Alabama  Free Size  Yellow  Spring
# 5                   41.0      California          S   Beige  Summer
# 6                   81.0       Wisconsin          M   Brown  Summer
# 7                   93.0       Tennessee  Free Size  Purple  Summer
# 8                   65.0         Florida  Free Size     Red  Spring
# 9                   60.0        Kentucky  Free Size  Yellow  Winter
#
#    Review Rating Subscription Status   Shipping Type Discount Applied  \
# 0       3.200000                  No        Standard               No
# 1       3.900000                 Yes   Free Shipping              Yes
# 2       3.100000                  No  2-Day Shipping               No
# 3       4.200000                  No    Store Pickup               No
# 4       3.600000                  No    Store Pickup               No
# 5       3.400000                  No  2-Day Shipping               No
# 6       3.790541                  No         Express              Yes
# 7       4.000000                  No    Store Pickup              Yes
# 8       4.300000                 Yes   Free Shipping              Yes
# 9       2.800000                 Yes    Store Pickup              Yes
#
#    Previous Purchases Payment Method Frequency of Purchases
# 0                36.0           Cash                 Weekly
# 1                20.0     Debit Card              Quarterly
# 2                18.0           Cash                Monthly
# 3                25.0           Cash               Annually
# 4                17.0    Credit Card                 Weekly
# 5                15.0         PayPal               Annually
# 6                 2.0          Venmo         Every 3 Months
# 7                18.0     Debit Card               Annually
# 8                28.0         PayPal              Bi-Weekly
# 9                 7.0           Cash                Monthly

# %%
df['Review Rating'] = df['Review Rating'].round(2)

# %%
df.head(10)
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
# 5         3583   23  Female         Shorts     Clothing
# 6         1135   62    Male        T-shirt     Clothing
# 7         1411   61    Male            Hat  Accessories
# 8          113   37    Male         Gloves  Accessories
# 9          166   42    Male        Handbag  Accessories
#
#    Purchase Amount (USD)        Location       Size   Color  Season  \
# 0                   68.0      California         XL   Olive  Winter
# 1                   84.0  South Carolina  Free Size   White  Spring
# 2                   50.0         Montana          M   Black  Winter
# 3                   75.0        Illinois  Free Size     Red    Fall
# 4                   80.0         Alabama  Free Size  Yellow  Spring
# 5                   41.0      California          S   Beige  Summer
# 6                   81.0       Wisconsin          M   Brown  Summer
# 7                   93.0       Tennessee  Free Size  Purple  Summer
# 8                   65.0         Florida  Free Size     Red  Spring
# 9                   60.0        Kentucky  Free Size  Yellow  Winter
#
#    Review Rating Subscription Status   Shipping Type Discount Applied  \
# 0           3.20                  No        Standard               No
# 1           3.90                 Yes   Free Shipping              Yes
# 2           3.10                  No  2-Day Shipping               No
# 3           4.20                  No    Store Pickup               No
# 4           3.60                  No    Store Pickup               No
# 5           3.40                  No  2-Day Shipping               No
# 6           3.79                  No         Express              Yes
# 7           4.00                  No    Store Pickup              Yes
# 8           4.30                 Yes   Free Shipping              Yes
# 9           2.80                 Yes    Store Pickup              Yes
#
#    Previous Purchases Payment Method Frequency of Purchases
# 0                36.0           Cash                 Weekly
# 1                20.0     Debit Card              Quarterly
# 2                18.0           Cash                Monthly
# 3                25.0           Cash               Annually
# 4                17.0    Credit Card                 Weekly
# 5                15.0         PayPal               Annually
# 6                 2.0          Venmo         Every 3 Months
# 7                18.0     Debit Card               Annually
# 8                28.0         PayPal              Bi-Weekly
# 9                 7.0           Cash                Monthly

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# #### Previous Purchases

# %%
# filling previous purchase with zero(0)
df['Previous Purchases'] = df['Previous Purchases'].fillna(0)

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases          0
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# #### Purchase Amount (USD)

# %%
df.groupby('Item Purchased')['Purchase Amount (USD)'].mean()
# Out:
# Item Purchased
# Backpack       60.111111
# Bag           735.773625
# Belt           59.993902
# Blouse         60.802326
# Boots          62.616438
# Coat           57.851852
# Dress          62.168675
# Gloves         60.550000
# Handbag        57.987261
# Hat            60.787097
# Headphones    831.344565
# Hoodie         58.059603
# Jacket         56.777108
# Jeans          60.456693
# Jewelry        59.011494
# Laptop        805.502027
# Pants          59.005848
# Phone         734.477349
# Sandals        57.527607
# Scarf          61.157233
# Shirt         279.935608
# Shoes         276.343790
# Shorts         60.073620
# Skirt          59.723270
# Sneakers       59.551724
# Socks          58.188679
# Sunglasses     59.975610
# Sweater        57.638554
# T-shirt        63.093333
# Watch         685.231471
# Name: Purchase Amount (USD), dtype: float64

# %%
# filling null values of Purchase Amount (USD) with the mean of each item purchased
df['Purchase Amount (USD)'] = df['Purchase Amount (USD)'].fillna(df.groupby('Item Purchased')['Purchase Amount (USD)'].transform('mean'))

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %% [markdown]
# #### Checking Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(50)

# %%
df.[duplicated()]
# Out:
#   Cell In[62], line 1
#     df.[duplicated()]
#        ^
# SyntaxError: invalid syntax

# %%
df[df.duplicated()]
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 886          2834   43  Female          Jeans     Clothing
# 1402         1621   25    Male            Hat  Accessories
# 1509          974   60    Male         Jacket    Outerwear
# 1600         2135   55    Male        Sandals     Footwear
# 1665         1846   51    Male        Sandals     Footwear
# 1797         3639   40  Female       Backpack  Accessories
# 1870         3456   49  Female        T-shirt     Clothing
# 2033         1812   42    Male           Belt  Accessories
# 2113         3040   59  Female         Blouse     Clothing
# 2226         1371   27    Male          Scarf  Accessories
# 2358         2977   30  Female           Coat    Outerwear
# 2447         2678   45  Female         Shorts     Clothing
# 2630          992   20    Male         Shorts     Clothing
# 2642         1566   58    Male     Sunglasses  Accessories
# 2739         2227   22    Male          Shirt     Clothing
# 2740         3487   51  Female         Shorts     Clothing
# 2800         2069   70    Male        Jewelry  Accessories
# 2905         2158   41    Male        Handbag  Accessories
# 2922         3334   55  Female          Jeans     Clothing
# 3036          258   20    Male        Handbag  Accessories
# 3065         3887   37  Female        Jewelry  Accessories
# 3185         1609   26    Male        Sandals     Footwear
# 3357         3091   29  Female          Shirt     Clothing
# 3390          603   37    Male          Shoes     Footwear
# 3538         1698   36    Male          Shirt     Clothing
# 3683         1209   20    Male          Boots     Footwear
# 3698          172   29    Male         Shorts     Clothing
# 3742          323   41    Male           Belt  Accessories
# 3810         2429   65    Male        T-shirt     Clothing
# 3843          615   68    Male        Jewelry  Accessories
# 3961         2558   70    Male         Shorts     Clothing
# 3987         3507   18  Female          Shirt     Clothing
# 4050         3287   45  Female         Jacket    Outerwear
# 4059          227   29    Male          Shoes     Footwear
# 4131         2642   25    Male     Sunglasses  Accessories
# 4183         1523   38    Male         Shorts     Clothing
# 4330         3716   63  Female     Sunglasses  Accessories
# 4390         3846   58  Female        Sweater     Clothing
# 4445         3644   53  Female          Scarf  Accessories
# 4468          473   20    Male          Jeans     Clothing
# 4513         1317   28    Male           Belt  Accessories
# 4558         3339   29  Female          Skirt     Clothing
# 4595         3577   29  Female          Boots     Footwear
# 4664         2689   53  Female        Handbag  Accessories
# 4717         2800   23  Female        T-shirt     Clothing
# 4735         2182   22    Male        Handbag  Accessories
# 4841         2622   48    Male          Shoes     Footwear
# 4887         3875   70  Female        Sweater     Clothing
# 4901         1060   22    Male         Jacket    Outerwear
# 5037         3439   26  Female          Shirt     Clothing
#
#       Purchase Amount (USD)        Location           Size      Color  Season  \
# 886                    56.0        Arkansas              M       Teal    Fall
# 1402                   47.0        Virginia      Free Size   Charcoal  Winter
# 1509                   75.0        Colorado              M       Teal    Fall
# 1600                   41.0        Virginia  Not Available     Maroon  Winter
# 1665                   78.0        Delaware  Not Available     Orange  Winter
# 1797                   20.0          Kansas      Free Size      Olive  Spring
# 1870                   89.0            Ohio              M     Orange    Fall
# 2033                   77.0       Wisconsin      Free Size       Blue  Summer
# 2113                   48.0         Alabama              L       Blue  Spring
# 2226                   67.0         Montana      Free Size      Peach  Summer
# 2358                   97.0        Nebraska              M     Silver  Summer
# 2447                   43.0     Connecticut              L      Olive  Spring
# 2630                   97.0       Wisconsin             XL      White  Spring
# 2642                   93.0           Idaho      Free Size      Peach    Fall
# 2739                   72.0        Missouri              L       Blue  Spring
# 2740                   89.0  North Carolina              L   Charcoal  Winter
# 2800                   81.0         Vermont      Free Size      Black  Summer
# 2905                   68.0     Mississippi      Free Size  Turquoise  Winter
# 2922                   35.0       Minnesota              M     Violet  Spring
# 3036                   53.0   West Virginia      Free Size        Red  Summer
# 3065                   92.0            Iowa      Free Size      Brown  Summer
# 3185                   58.0        Nebraska  Not Available       Cyan    Fall
# 3357                   36.0           Texas              M      Peach  Summer
# 3390                   58.0          Oregon  Not Available   Lavender  Summer
# 3538                   87.0  South Carolina              L   Lavender    Fall
# 3683                  100.0       Wisconsin  Not Available        Red  Winter
# 3698                   35.0        Virginia              M       Blue  Summer
# 3742                   95.0       Tennessee      Free Size       Cyan  Winter
# 3810                   38.0           Idaho              M     Violet  Spring
# 3843                   85.0           Idaho      Free Size   Lavender  Winter
# 3961                   23.0        Oklahoma              L       Cyan  Spring
# 3987                   57.0        Illinois              L      Olive  Winter
# 4050                   67.0        Illinois              L       Pink  Winter
# 4059                   74.0           Texas  Not Available     Violet  Spring
# 4131                   60.0         Vermont      Free Size      Olive  Winter
# 4183                   72.0       Tennessee              L     Yellow  Spring
# 4330                   34.0        Nebraska      Free Size     Orange    Fall
# 4390                   52.0      California              M      Green  Winter
# 4445                   96.0       Tennessee      Free Size    Magenta    Fall
# 4468                   39.0         Georgia              L       Gray  Winter
# 4513                   32.0        Arkansas      Free Size   Lavender  Spring
# 4558                   94.0       Minnesota              L      White  Winter
# 4595                   24.0           Maine  Not Available     Yellow  Spring
# 4664                   63.0   West Virginia      Free Size  Turquoise  Spring
# 4717                   89.0           Maine              L       Pink  Spring
# 4735                   63.0          Hawaii      Free Size      Black    Fall
# 4841                   46.0           Maine  Not Available      Beige  Winter
# 4887                   54.0          Nevada             XL      Beige  Summer
# 4901                   34.0  North Carolina              M      Beige  Winter
# 5037                   71.0        Kentucky              M     Violet    Fall
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 886            3.30                  No   Free Shipping               No
# 1402           3.10                  No  2-Day Shipping              Yes
# 1509           3.50                 Yes  2-Day Shipping              Yes
# 1600           2.90                  No        Standard               No
# 1665           2.80                  No  2-Day Shipping               No
# 1797           4.60                  No         Express               No
# 1870           4.70                  No        Standard               No
# 2033           3.60                  No        Standard               No
# 2113           3.20                  No    Next Day Air               No
# 2226           3.70                  No  2-Day Shipping              Yes
# 2358           2.80                  No         Express               No
# 2447           3.80                  No    Next Day Air               No
# 2630           2.70                 Yes        Standard              Yes
# 2642           4.20                  No   Free Shipping              Yes
# 2739           4.80                  No    Store Pickup               No
# 2740           4.90                  No        Standard               No
# 2800           3.90                  No    Store Pickup               No
# 2905           4.00                  No    Next Day Air               No
# 2922           4.20                  No         Express               No
# 3036           4.50                 Yes         Express              Yes
# 3065           3.90                  No         Express               No
# 3185           4.60                  No    Next Day Air              Yes
# 3357           4.90                  No    Store Pickup               No
# 3390           4.20                 Yes    Next Day Air              Yes
# 3538           3.50                  No    Next Day Air               No
# 3683           3.81                  No  2-Day Shipping              Yes
# 3698           3.60                 Yes    Store Pickup              Yes
# 3742           3.00                 Yes        Standard              Yes
# 3810           4.40                  No    Next Day Air               No
# 3843           4.00                 Yes        Standard              Yes
# 3961           3.90                  No        Standard               No
# 3987           3.70                  No  2-Day Shipping               No
# 4050           5.00                  No         Express               No
# 4059           3.30                 Yes   Free Shipping              Yes
# 4131           2.70                  No    Next Day Air               No
# 4183           4.80                  No   Free Shipping              Yes
# 4330           3.40                  No   Free Shipping               No
# 4390           4.90                  No        Standard               No
# 4445           3.20                  No        Standard               No
# 4468           3.90                 Yes   Free Shipping              Yes
# 4513           4.60                  No        Standard              Yes
# 4558           2.90                  No  2-Day Shipping               No
# 4595           3.00                  No         Express               No
# 4664           2.90                  No  2-Day Shipping               No
# 4717           3.90                  No   Free Shipping               No
# 4735           3.20                  No   Free Shipping               No
# 4841           3.00                  No         Express               No
# 4887           3.90                  No  2-Day Shipping               No
# 4901           2.50                  No        Standard              Yes
# 5037           3.00                  No    Store Pickup               No
#
#       Previous Purchases Payment Method Frequency of Purchases
# 886                 19.0           Cash                Monthly
# 1402                27.0         PayPal         Every 3 Months
# 1509                30.0  Bank Transfer              Quarterly
# 1600                35.0    Credit Card            Fortnightly
# 1665                39.0  Bank Transfer              Quarterly
# 1797                50.0         PayPal              Bi-Weekly
# 1870                13.0          Venmo               Annually
# 2033                33.0  Bank Transfer               Annually
# 2113                31.0         PayPal              Bi-Weekly
# 2226                41.0  Bank Transfer         Every 3 Months
# 2358                28.0           Cash            Fortnightly
# 2447                 6.0         PayPal         Every 3 Months
# 2630                40.0  Bank Transfer              Bi-Weekly
# 2642                48.0         PayPal               Annually
# 2739                28.0           Cash               Annually
# 2740                 6.0         PayPal                 Weekly
# 2800                44.0          Venmo                Monthly
# 2905                41.0          Venmo            Fortnightly
# 2922                 3.0         PayPal                Monthly
# 3036                 5.0    Credit Card              Quarterly
# 3065                40.0     Debit Card              Quarterly
# 3185                12.0  Bank Transfer              Bi-Weekly
# 3357                15.0  Bank Transfer              Quarterly
# 3390                10.0           Cash         Every 3 Months
# 3538                48.0    Credit Card         Every 3 Months
# 3683                 8.0     Debit Card               Annually
# 3698                 4.0    Credit Card                 Weekly
# 3742                47.0    Credit Card                Monthly
# 3810                34.0     Debit Card               Annually
# 3843                21.0    Credit Card              Bi-Weekly
# 3961                17.0         PayPal            Fortnightly
# 3987                12.0           Cash            Fortnightly
# 4050                 4.0          Venmo            Fortnightly
# 4059                 5.0         PayPal                Monthly
# 4131                20.0  Bank Transfer         Every 3 Months
# 4183                 5.0     Debit Card                Monthly
# 4330                 2.0  Bank Transfer                Monthly
# 4390                46.0          Venmo               Annually
# 4445                47.0     Debit Card               Annually
# 4468                 3.0  Bank Transfer              Quarterly
# 4513                14.0     Debit Card              Bi-Weekly
# 4558                46.0    Credit Card                Monthly
# 4595                12.0          Venmo              Bi-Weekly
# 4664                18.0    Credit Card         Every 3 Months
# 4717                 9.0  Bank Transfer         Every 3 Months
# 4735                32.0  Bank Transfer              Bi-Weekly
# 4841                21.0  Bank Transfer               Annually
# 4887                33.0    Credit Card              Bi-Weekly
# 4901                25.0     Debit Card                Monthly
# 5037                33.0    Credit Card                Monthly

# %%
df[df['Customer ID'] == 974	]
# Out:
#       Customer ID  Age Gender Item Purchased   Category  \
# 483           974   60   Male         Jacket  Outerwear
# 1509          974   60   Male         Jacket  Outerwear
#
#       Purchase Amount (USD)  Location Size Color Season  Review Rating  \
# 483                    75.0  Colorado    M  Teal   Fall            3.5
# 1509                   75.0  Colorado    M  Teal   Fall            3.5
#
#      Subscription Status   Shipping Type Discount Applied  Previous Purchases  \
# 483                  Yes  2-Day Shipping              Yes                30.0
# 1509                 Yes  2-Day Shipping              Yes                30.0
#
#      Payment Method Frequency of Purchases
# 483   Bank Transfer              Quarterly
# 1509  Bank Transfer              Quarterly

# %%
len(df)
# Out:
# 5050

# %%
# Deleting duplicate records 
df = df.drop_duplicates(subset = ['Customer ID'] , keep = 'first')

# %%
len(df)
# Out:
# 5000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.count()
# Out:
# Customer ID               5000
# Age                       5000
# Gender                    5000
# Item Purchased            5000
# Category                  5000
# Purchase Amount (USD)     5000
# Location                  5000
# Size                      5000
# Color                     5000
# Season                    5000
# Review Rating             5000
# Subscription Status       5000
# Shipping Type             5000
# Discount Applied          5000
# Previous Purchases        5000
# Payment Method            5000
# Frequency of Purchases    5000
# dtype: int64

# %% [markdown]
# #### Renaming the headers for sql

# %%
df.columnd = df.columns.str.replace(" ","_")
# Out:
# C:\Users\Prabhat\AppData\Local\Temp\ipykernel_11752\1038755236.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.columnd = df.columns.str.replace(" ","_")

# %%
df.columns = df.columns.str.replace(" ","_")
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases'],
#       dtype='str')

# %%
# replacing purchase_amount_(usd) to purchase_amount
df = df.rename(columns = {"purchase_amount_(usd)" : "purchase_amount"})

# %%
df.column
# Out:
# -------------------------------------------------------------------
# AttributeError                    Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 df.column
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases'],
#       dtype='str')

# %%
df.head()
# Out:
#    customer_id  age  gender item_purchased     category  purchase_amount  \
# 0         2701   22  Female        T-shirt     Clothing             68.0
# 1          521   51    Male     Sunglasses  Accessories             84.0
# 2         3157   18  Female          Shirt     Clothing             50.0
# 3         1687   22    Male         Gloves  Accessories             75.0
# 4         2929   40  Female        Jewelry  Accessories             80.0
#
#          location       size   color  season  review_rating  \
# 0      California         XL   Olive  Winter            3.2
# 1  South Carolina  Free Size   White  Spring            3.9
# 2         Montana          M   Black  Winter            3.1
# 3        Illinois  Free Size     Red    Fall            4.2
# 4         Alabama  Free Size  Yellow  Spring            3.6
#
#   subscription_status   shipping_type discount_applied  previous_purchases  \
# 0                  No        Standard               No                36.0
# 1                 Yes   Free Shipping              Yes                20.0
# 2                  No  2-Day Shipping               No                18.0
# 3                  No    Store Pickup               No                25.0
# 4                  No    Store Pickup               No                17.0
#
#   payment_method frequency_of_purchases
# 0           Cash                 Weekly
# 1     Debit Card              Quarterly
# 2           Cash                Monthly
# 3           Cash               Annually
# 4    Credit Card                 Weekly

# %% [markdown]
# #### Connection to SQL Server

# %%
# !pip install pyodbc sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pyodbc
#   Obtaining dependency information for pyodbc from https://files.pythonhosted.org/packages/c0/70/5e61b216cc13c7f833ef87f4cdeab253a7873f8709253f5076e9bb16c1b3/pyodbc-5.3.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading pyodbc-5.3.0-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Collecting sqlalchemy
#   Obtaining dependency information for sqlalchemy from https://files.pythonhosted.org/packages/47/9e/fd90114059175cac64e4fafa9bf3ac20584384d66de40793ae2e2f26f3bb/sqlalchemy-2.0.49-cp312-cp312-win_amd64.whl.metadata
#   Downloading sqlalchemy-2.0.49-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Collecting greenlet>=1 (from sqlalchemy)
#   Obtaining dependency information for greenlet>=1 from https://files.pythonhosted.org/packages/4c/fe/4fb3a0805bd5165da5ebf858da7cc01cce8061674106d2cf5bdab32cbfde/greenlet-3.5.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading greenlet-3.5.0-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\prabhat\appdata\roaming\python\python312\site-packages (from sqlalchemy) (4.15.0)
# Downloading pyodbc-5.3.0-cp312-cp312-win_amd64.whl (70 kB)
#    ---------------------------------------- 0.0/70.1 kB ? eta -:--:--
#    ----------------------- ---------------- 41.0/70.1 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 70.1/70.1 kB 767.9 kB/s eta 0:00:00
# Downloading sqlalchemy-2.0.49-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/2.1 MB 5.9 MB/s eta 0:00:01
#    -------- ------------------------------- 0.4/2.1 MB 5.4 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/2.1 MB 5.9 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 6.3 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.1 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 5.9 MB/s eta 0:00:00
# Downloading greenlet-3.5.0-cp312-cp312-win_amd64.whl (238 kB)
#    ---------------------------------------- 0.0/238.8 kB ? eta -:--:--
#    ---------------------------------------- 238.8/238.8 kB 7.4 MB/s eta 0:00:00
# Installing collected packages: pyodbc, greenlet, sqlalchemy
# Successfully installed greenlet-3.5.0 pyodbc-5.3.0 sqlalchemy-2.0.49
# [notice] A new release of pip is available: 23.2.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mysql-connector-python
#   Obtaining dependency information for mysql-connector-python from https://files.pythonhosted.org/packages/38/55/4ebb602d270108ea6e81ccdfe4aa0a511fedffdc3ef6c193ac9ff76402fe/mysql_connector_python-9.7.0-py2.py3-none-any.whl.metadata
#   Downloading mysql_connector_python-9.7.0-py2.py3-none-any.whl.metadata (11 kB)
# Downloading mysql_connector_python-9.7.0-py2.py3-none-any.whl (480 kB)
#    ---------------------------------------- 0.0/480.6 kB ? eta -:--:--
#     --------------------------------------- 10.2/480.6 kB ? eta -:--:--
#    -- ------------------------------------ 30.7/480.6 kB 325.1 kB/s eta 0:00:02
#    --- ----------------------------------- 41.0/480.6 kB 279.3 kB/s eta 0:00:02
#    --- ----------------------------------- 41.0/480.6 kB 279.3 kB/s eta 0:00:02
#    --- ----------------------------------- 41.0/480.6 kB 279.3 kB/s eta 0:00:02
#    ------ -------------------------------- 81.9/480.6 kB 286.7 kB/s eta 0:00:02
#    ------ -------------------------------- 81.9/480.6 kB 286.7 kB/s eta 0:00:02
#    ------- ------------------------------- 92.2/480.6 kB 227.6 kB/s eta 0:00:02
#    ------- ------------------------------- 92.2/480.6 kB 227.6 kB/s eta 0:00:02
#    -------- ----------------------------- 112.6/480.6 kB 226.0 kB/s eta 0:00:02
#    -------- ----------------------------- 112.6/480.6 kB 226.0 kB/s eta 0:00:02
#    ----------- -------------------------- 143.4/480.6 kB 236.4 kB/s eta 0:00:02
#    ----------- -------------------------- 143.4/480.6 kB 236.4 kB/s eta 0:00:02
#    ------------ ------------------------- 163.8/480.6 kB 234.1 kB/s eta 0:00:02
#    ------------ ------------------------- 163.8/480.6 kB 234.1 kB/s eta 0:00:02
#    --------------- ---------------------- 194.6/480.6 kB 240.6 kB/s eta 0:00:02
#    --------------- ---------------------- 194.6/480.6 kB 240.6 kB/s eta 0:00:02
#    --------------- ---------------------- 194.6/480.6 kB 240.6 kB/s eta 0:00:02
#    ---------------- --------------------- 204.8/480.6 kB 222.4 kB/s eta 0:00:02
#    ---------------- --------------------- 204.8/480.6 kB 222.4 kB/s eta 0:00:02
#    ---------------- --------------------- 204.8/480.6 kB 222.4 kB/s eta 0:00:02
#    ------------------- ------------------ 245.8/480.6 kB 231.8 kB/s eta 0:00:02
#    -------------------- ----------------- 256.0/480.6 kB 228.0 kB/s eta 0:00:01
#    --------------------- ---------------- 276.5/480.6 kB 233.3 kB/s eta 0:00:01
#    --------------------- ---------------- 276.5/480.6 kB 233.3 kB/s eta 0:00:01
#    ---------------------- --------------- 286.7/480.6 kB 229.8 kB/s eta 0:00:01
#    ------------------------- ------------ 327.7/480.6 kB 250.7 kB/s eta 0:00:01
#    ------------------------- ------------ 327.7/480.6 kB 250.7 kB/s eta 0:00:01
#    -------------------------- ----------- 337.9/480.6 kB 238.3 kB/s eta 0:00:01
#    -------------------------- ----------- 337.9/480.6 kB 238.3 kB/s eta 0:00:01
#    -------------------------- ----------- 337.9/480.6 kB 238.3 kB/s eta 0:00:01
#    ----------------------------- -------- 368.6/480.6 kB 241.3 kB/s eta 0:00:01
#    ----------------------------- -------- 378.9/480.6 kB 233.6 kB/s eta 0:00:01
#    -------------------------------- ----- 409.6/480.6 kB 250.5 kB/s eta 0:00:01
#    --------------------------------- ---- 419.8/480.6 kB 249.6 kB/s eta 0:00:01
#    ----------------------------------- -- 450.6/480.6 kB 256.1 kB/s eta 0:00:01
#    -------------------------------------  471.0/480.6 kB 263.3 kB/s eta 0:00:01
#    -------------------------------------- 480.6/480.6 kB 261.8 kB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.7.0
# [notice] A new release of pip is available: 23.2.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine
import pandas as pd

# MySQL Workbench details
username = "root"                        # Apna MySQL username
password = "your_password"              # Apna MySQL password
host = "localhost"                       
database = "customer_behavior_analysis" # Hamara database naam

# Connection banana
engine = create_engine(
    f"mysql+mysqlconnector://{username}:{password}@{host}/{database}"
)

print("✅ Successfully Connected to MySQL Workbench!")
# Out:
# ✅ Successfully Connected to MySQL Workbench!

# %%
from sqlalchemy import create_engine
import pandas as pd

# MySQL Workbench details
username = "root"
password = "targetNDA@123"
host = "localhost"
port = 3306
database = "customer_behavior_analysis"

# Connection banana
engine = create_engine(
    f"mysql+mysqlconnector://{username}:{password}@{host}:{port}/{database}"
)

print("✅ Successfully Connected to MySQL Workbench!")
# Out:
# ✅ Successfully Connected to MySQL Workbench!

# %%
# DataFrame ko MySQL mein bhejo
df.to_sql(
    name='customer_behavior',   # Table ka naam jo MySQL mein banega
    con=engine,
    if_exists='replace',        # Agar table hai toh replace karo
    index=False                 # Index mat bhejo
)

print("✅ Data Successfully Sent to MySQL Workbench!")
# Out:
# -------------------------------------------------------------------
# gaierror                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\network.py:764, in MySQLTCPSocket.open_connection(self)
#     763 try:
# --> 764     addrinfos = socket.getaddrinfo(
#     765         self.server_host,
#     766         self.server_port,
#     767         0,
#     768         socket.SOCK_STREAM,
#     769         socket.SOL_TCP,
#     770     )
#     771     # If multiple results we favor IPv4, unless IPv6 was forced.
#
# File C:\Program Files\Python312\Lib\socket.py:963, in getaddrinfo(host, port, family, type, proto, flags)
#     962 addrlist = []
# --> 963 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     964     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11003] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# InterfaceError                    Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\base.py:3317, in Engine.raw_connection(self)
#    3296 """Return a "raw" DBAPI connection from the connection pool.
#    3297
#    3298 The returned object is a proxied version of the DBAPI
#    (...)   3315
#    3316 """
# -> 3317 return self.pool.connect()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     441 """Return a DBAPI connection from the pool.
#     442
#     443 The connection is instrumented such that when its
#    (...)    446
#     447 """
# --> 448 return _ConnectionFairy._checkout(self)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\pool\base.py:1272, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1271 if not fairy:
# -> 1272     fairy = _ConnectionRecord.checkout(pool)
#    1274     if threadconns is not None:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     176 except:
# --> 177     with util.safe_reraise():
#     178         self._dec_overflow()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\util\langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\pool\impl.py:175, in QueuePool._do_get(self)
#     174 try:
# --> 175     return self._create_connection()
#     176 except:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\pool\base.py:389, in Pool._create_connection(self)
#     387 """Called by subclasses to create a new ConnectionRecord."""
# --> 389 return _ConnectionRecord(self)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\util\langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\create.py:667, in create_engine.<locals>.connect(connection_record)
#     666 else:
# --> 667     return dialect.connect(*cargs_tup, **cparams)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\pooling.py:323, in connect(*args, **kwargs)
#     322     return CMySQLConnection(*args, **kwargs)
# --> 323 return MySQLConnection(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\connection.py:185, in MySQLConnection.__init__(self, **kwargs)
#     184 try:
# --> 185     self.connect(**kwargs)
#     186 except Exception:
#     187     # Tidy-up underlying socket on failure
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\abstracts.py:1604, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1603 self.disconnect()
# -> 1604 self._open_connection()
#    1606 charset, collation = (
#    1607     kwargs.pop("charset", None),
#    1608     kwargs.pop("collation", None),
#    1609 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\connection.py:411, in MySQLConnection._open_connection(self)
#     407         raise ConnectionTimeoutError(
#     408             errno=err.errno,
#     409             msg=err.msg,
#     410         ) from err
# --> 411     raise err
#     412 finally:
#     413     # as the connection is established, set back the read
#     414     # and write timeouts to the original value
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\connection.py:382, in MySQLConnection._open_connection(self)
#     381 try:
# --> 382     self._socket.open_connection()
#     384     # do initial handshake
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\network.py:784, in MySQLTCPSocket.open_connection(self)
#     783 except IOError as err:
# --> 784     raise InterfaceError(
#     785         errno=2003,
#     786         values=(self.server_host, self.server_port, _strioerror(err)),
#     787     ) from err
#     789 (self._family, socktype, proto, _, sockaddr) = addrinfo
#
# InterfaceError: 2003: Can't connect to MySQL server on '123@localhost:3306' (Errno 11003: getaddrinfo failed)
#
# The above exception was the direct cause of the following exception:
#
# InterfaceError                    Traceback (most recent call last)
# Cell In[83], line 2
#       1 # DataFrame ko MySQL mein bhejo
# ----> 2 df.to_sql(
#       3     name='customer_behavior',   # Table ka naam jo MySQL mein banega
#       4     con=engine,
#       5     if_exists='replace',        # Agar table hai toh replace karo
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:3052, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    3048         3
#    3049         """  # noqa: E501
#    3050         from pandas.io import sql
#    3051
# -> 3052         return sql.to_sql(
#    3053             self,
#    3054             name,
#    3055             con,
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\io\sql.py:840, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     835 elif not isinstance(frame, DataFrame):
#     836     raise NotImplementedError(
#     837         "'frame' argument should be either a Series or a DataFrame"
#     838     )
# --> 840 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
#     841     return pandas_sql.to_sql(
#     842         frame,
#     843         name,
#    (...)    852         **engine_kwargs,
#     853     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\io\sql.py:908, in pandasSQL_builder(con, schema, need_transaction)
#     902     raise ImportError(
#     903         f"Using URI string without version '{VERSIONS['sqlalchemy']}' or newer "
#     904         "of 'sqlalchemy' installed."
#     905     )
#     907 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 908     return SQLDatabase(con, schema, need_transaction)
#     910 adbc = import_optional_dependency("adbc_driver_manager.dbapi", errors="ignore")
#     911 if adbc and isinstance(con, adbc.Connection):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\io\sql.py:1649, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1647     self.exit_stack.callback(con.dispose)
#    1648 if isinstance(con, Engine):
# -> 1649     con = self.exit_stack.enter_context(con.connect())
#    1650 if need_transaction and not con.in_transaction():
#    1651     self.exit_stack.enter_context(con.begin())
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\base.py:3293, in Engine.connect(self)
#    3270 def connect(self) -> Connection:
#    3271     """Return a new :class:`_engine.Connection` object.
#    3272
#    3273     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)   3290
#    3291     """
# -> 3293     return self._connection_cls(self)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
# --> 145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#     148         raise
#     149 else:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\base.py:2448, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2446 elif should_wrap:
#    2447     assert sqlalchemy_exception is not None
# -> 2448     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2449 else:
#    2450     assert exc_info[1] is not None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     141 if connection is None:
#     142     try:
# --> 143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
#     145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\base.py:3317, in Engine.raw_connection(self)
#    3295 def raw_connection(self) -> PoolProxiedConnection:
#    3296     """Return a "raw" DBAPI connection from the connection pool.
#    3297
#    3298     The returned object is a proxied version of the DBAPI
#    (...)   3315
#    3316     """
# -> 3317     return self.pool.connect()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     440 def connect(self) -> PoolProxiedConnection:
#     441     """Return a DBAPI connection from the pool.
#     442
#     443     The connection is instrumented such that when its
#    (...)    446
#     447     """
# --> 448     return _ConnectionFairy._checkout(self)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\pool\base.py:1272, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1264 @classmethod
#    1265 def _checkout(
#    1266     cls,
#    (...)   1269     fairy: Optional[_ConnectionFairy] = None,
#    1270 ) -> _ConnectionFairy:
#    1271     if not fairy:
# -> 1272         fairy = _ConnectionRecord.checkout(pool)
#    1274         if threadconns is not None:
#    1275             threadconns.current = weakref.ref(fairy)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     175     return self._create_connection()
#     176 except:
# --> 177     with util.safe_reraise():
#     178         self._dec_overflow()
#     179     raise
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\util\langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     119     assert exc_value is not None
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#     123     self._exc_info = None  # remove potential circular references
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\pool\impl.py:175, in QueuePool._do_get(self)
#     173 if self._inc_overflow():
#     174     try:
# --> 175         return self._create_connection()
#     176     except:
#     177         with util.safe_reraise():
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\pool\base.py:389, in Pool._create_connection(self)
#     386 def _create_connection(self) -> ConnectionPoolEntry:
#     387     """Called by subclasses to create a new ConnectionRecord."""
# --> 389     return _ConnectionRecord(self)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     898     self.fresh = True
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\util\langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     119     assert exc_value is not None
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#     123     self._exc_info = None  # remove potential circular references
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\create.py:667, in create_engine.<locals>.connect(connection_record)
#     665     return dialect.connect(*mutable_cargs, **mutable_cparams)
#     666 else:
# --> 667     return dialect.connect(*cargs_tup, **cparams)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sqlalchemy\engine\default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\pooling.py:323, in connect(*args, **kwargs)
#     321 if CMySQLConnection and not use_pure:
#     322     return CMySQLConnection(*args, **kwargs)
# --> 323 return MySQLConnection(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\connection.py:185, in MySQLConnection.__init__(self, **kwargs)
#     183 if kwargs:
#     184     try:
# --> 185         self.connect(**kwargs)
#     186     except Exception:
#     187         # Tidy-up underlying socket on failure
#     188         self.close()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\abstracts.py:1604, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1601     self.config(**kwargs)
#    1603 self.disconnect()
# -> 1604 self._open_connection()
#    1606 charset, collation = (
#    1607     kwargs.pop("charset", None),
#    1608     kwargs.pop("collation", None),
#    1609 )
#    1610 if charset or collation:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\connection.py:411, in MySQLConnection._open_connection(self)
#     406     if isinstance(err, (ReadTimeoutError, WriteTimeoutError)):
#     407         raise ConnectionTimeoutError(
#     408             errno=err.errno,
#     409             msg=err.msg,
#     410         ) from err
# --> 411     raise err
#     412 finally:
#     413     # as the connection is established, set back the read
#     414     # and write timeouts to the original value
#     415     self.read_timeout = stored_read_timeout
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\connection.py:382, in MySQLConnection._open_connection(self)
#     380 self._socket = self._get_connection()
#     381 try:
# --> 382     self._socket.open_connection()
#     384     # do initial handshake
#     385     self._do_handshake()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mysql\connector\network.py:784, in MySQLTCPSocket.open_connection(self)
#     782         addrinfo = addrinfos[0]
#     783 except IOError as err:
# --> 784     raise InterfaceError(
#     785         errno=2003,
#     786         values=(self.server_host, self.server_port, _strioerror(err)),
#     787     ) from err
#     789 (self._family, socktype, proto, _, sockaddr) = addrinfo
#     791 # Instantiate the socket and connect
#
# InterfaceError: (mysql.connector.errors.InterfaceError) 2003: Can't connect to MySQL server on '123@localhost:3306' (Errno 11003: getaddrinfo failed)
# (Background on this error at: https://sqlalche.me/e/20/rvf5)

# %%
from sqlalchemy import create_engine
import urllib.parse
import pandas as pd

# MySQL Workbench details
username = "root"
password = password = urllib.parse.quote_plus("targetNDA@123")
host = "localhost"
port = 3306
database = "customer_behavior_analysis"

# Connection banana
engine = create_engine(
    f"mysql+mysqlconnector://{username}:{password}@{host}:{port}/{database}"
)

print("✅ Successfully Connected to MySQL Workbench!")
# Out:
# ✅ Successfully Connected to MySQL Workbench!

# %%
# DataFrame ko MySQL mein bhejo
df.to_sql(
    name='customer_behavior',   # Table ka naam jo MySQL mein banega
    con=engine,
    if_exists='replace',        # Agar table hai toh replace karo
    index=False                 # Index mat bhejo
)

print("✅ Data Successfully Sent to MySQL Workbench!")
# Out:
# ✅ Data Successfully Sent to MySQL Workbench!
